# %% [markdown]
# <a href="https://colab.research.google.com/github/andre2564/SistemaPredictivoAtaquesCardiacos/blob/main/EntendimientoDeLosDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Parcial 1 - Enendimiento de los datos**
#
# En este trabajo se busca definir el contexto inicial para unproyecto de analítica de datos.

# %% [markdown]
# # Sistemas de prediccion de Ataques Cardiacos

# %% [markdown]
# **Datos de la presentación**
#
#
# * **Curso**: 901T
#
# * **Autores**:
#
# 1. Andrea Roa Perez

# %% [markdown]
# # Fase 2: Comprensión de los datos

# %% [markdown]
# ## Orígenes de datos (1.0)
#
# Describir de forma general que se puede encontrar en este origen. Indicar si es interno, externo, se piensa adquirir o se necesita capturar (como pueden ser las encuestas por realizar).
#
# También se debe considerar si es necesario cruzar o unir con otro origen de datos.

# %% [markdown]
# *Repetir esta celda para cada origen de datos*
#
# **--- Origen 1 ---**
#
# **Nombre**: Behavioral Risk Factor Surveillance System / Sistema de Vigilancia de Factores de Riesgo del Comportamiento.
#
# | Tablero de control de los datos | Filas | Columnas | Descripción |
# | --- | --- | --- | --- |
# | Cantidad de datos | 441000 | 330 | datos personales, salud, habitos |
# | Hipótesis relacionada con los objetivos del proyecto | 441000 | 29 | hay datos que sobran para el analisis necesario, por ende se requiere filtrar unicamente aquellos con interes medico de todo el dataset |
#
#
# **Forma de almacenamiento**:
# archivo csv
#
#
#
# **Ubicación de los datos**:
# obtenidos de BRFSS incluyen el consumo de tabaco, la cobertura de atención médica, actividad física y consumo de frutas y verduras. Los datos se generaron a través de una encuesta telefónica. no se requiere solicitar acceso pero si es importante tener acceso al libro de codigos brindado por la organizacion para el entendimiento de los datos

# %% [markdown]
# ## Descripción de los datos (1.3)

# %% [markdown]
# *Repetir esta celda para cada origen de datos*
#
# **--- Origen 1 ---**
#
# **Nombre**: Behavioral Risk Factor Surveillance System / Sistema de Vigilancia de Factores de Riesgo del Comportamiento.
# Describa cada uno de los atributos disponibles en el conjunto de datos
#
# | Atributo | Tipo de datos | Naturaleza | Descripción |
# | --- | --- | --- | --- |
# | _STATE | Numerico | Discreta |Código FIPS estatal	Numérico	Asignación del estado de USA por números desde el 1	0 |
# |FMONTH	|Numerico|Discreta |Asignación del mes por número desde el 1	0|
# |IDATE|char|Continua |Fecha de la entrevista|
# |IMONTH	|char|Continua |Mes de la entrevista|
# |IDAY| char	|Continua |Día de la entrevista|
# |IYEAR|	char|Continua |Año de la entrevista|
# |DISPCODE|	numerico|Categorica(Nominal)|Disposición final|
# |SEQNO|	Numerico|Continua |Número de secuencia anual|
# |_PSU|	Numerico |Continua | Unidad primaria de muestreo|
# |CTELENUM|	Numerico | Categorica(Nominal)|¿Número de teléfono correcto?|
# |PVTRESD1|	Numerico |Categorica(Nominal) |residencia privada|
# |COLGHOUS|	Numerico | Categorica(Nominal)|¿Vives en viviendas universitarias?|
# |STATERES|	Numerico | Categorica(Nominal) |¿Reside en x estado?|
# |CELLFON3|	Numerico | Categorica(Nominal) |¿Es esto un teléfono celular?|
# |LADULT|	Numerico | Categorica(Nominal)|¿Tiene más de 18 años?	|
# |NUMADULT|	Numerico | Discreta |Número de adultos en el hogar|
# |NUMMEN|	Numerico |Discreta | Número de hombres adultos en el hogar|
# |NUMWOMEN|	Numerico | Discreta |Número de mujeres adultas en el hogar|
# |CTELNUM1|	Numerico |Categorica(Nominal) | ¿Número de teléfono correcto?|
# |CELLFON2|	Numerico |Categorica(Nominal) | ¿Esto es un teléfono celular?|
# |CADULT|	Numerico |Categorica(Nominal) | ¿Tiene más de 18 años?|
# |PVTRESD2|	Numerico |Categorica(Nominal) | ¿Vive en una residencia privada? (No dormitorio, No vivienda grupal)	|
# |CCLGHOUS|	Numerico | Categorica(Nominal) |¿Vives en viviendas universitarias?|
# |CSTATE|	Numerico | Categorica(Nominal)|¿es usted residente de x estado?	|
# |LANDLINE|	Numerico | Categorica(Nominal) |¿También tiene un teléfono fijo en su hogar que usa para hacer y recibir llamadas?	|
# |HHADULT|	Numerico | Discreta |Número de adultos en el hogar con 18 años o más|
# |GENHLTH|	Numerico | Categorica(Ordinal) |Estado de salud en general	|
# |PHYSHLTH|	Numerico | Categorica(Nominal)-Discreta |Su salud física, incluyendo enfermedades físicas y lesiones ¿Cuántos días durante los últimos 30 días su salud un fue buena?	|
# |MENTHLTH|	Numerico |Categorica(Nominal)-Discreta | Su salud mental. Que incluye estrés, depresión y problemas con las emociones, ¿Cuantos días durante los últimos 30 días su salud mental no fue buena?|
# |POORHLTH|	Numerico |Categorica(Nominal)-Discreta | Durante los últimos 30 días, ¿Durante cuántos días la mala salud y física mental le impidió hacer sus actividades habituales? (Cuidado personal, trabajo, recreación)|
# |HLTHPLN1|	Numerico |Categorica(Nominal) | ¿Tiene algún tipo de cobertura médica?|
# |PERSDOC2|	Numerico |Categorica(Nominal)| ¿Tiene alguna persona a la que considere su médico personal o proveedor de atención medica?|
# |MEDCOST|	Numerico |Categorica(Nominal) | ¿Hubo algún momento en los últimos 12 meses en que necesito ver a un médico, pero no pudo debido al costo?|
# |CHECKUP1|	Numerico |Categorica(Nominal) | Ultimo chequeo médico de rutina|
# |BPHIGH4|	Numerico |Categorica(Nominal) | Diagnóstico de tensión arterial alta/hipertensión|
# |BPMEDS|	Numerico |Categorica(Nominal) | ¿Actualmente toma medicamentos para la presión arterial?|
# |BLOODCHO|	Numerico |Categorica(Nominal) | ¿Alguna vez se ha controlado el colesterol en la sangre?|
# |CHOLCHK|	Numerico | Categorica(Nominal) |¿Cuánto tiempo ha pasado desde la última vez que se controló el colesterol en la sangre?|
# |TOLDHI2|	Numerico | Categorica(Nominal) |Diagnóstico de colesterol alto en la sangre|
# |CVDINFR4|	Numerico |Categorica(Nominal) | Diagnóstico ataque al corazón|
# |CVDCRHD4|	Numerico |Categorica(Nominal) | Diagnóstico algina de pecho o enfermedad coronaria|
# |CVDSTRK3|	Numerico |Categorica(Nominal) | Diagnóstico de derrame cerebral|
# |ASTHMA3|	Numerico |Categorica(Nominal) | Diagnóstico de asma|
# |ASTHNOW|	Numerico | Categorica(Nominal) |¿Actualmente tiene asma?	|
# |CHCSCNCR|	Numerico |Categorica(Nominal) | Diagnóstico cáncer de piel	|
# |CHCOCNCR|	Numerico |Categorica(Nominal) | Diagnóstico de otro tipo de cáncer	|
# |CHCCOPD1|	Numerico |Categorica(Nominal) | Diagnóstico de enfermedad pulmonar obstructiva crónica como EPOC o bronquitis crónica|
# |HAVARTH3|	Numerico |Categorica(Nominal) | Diagnóstico de algún tipo de artritis, artritis reumatoide, gota, lupus o fibromialgia	|
# |ADDEPEV2|	Numerico |Categorica(Nominal) | Diagnóstico de trastorno depresivo, que incluye depresión, depresión mayor, distimia o depresión menor|
# |CHCKIDNY|	Numerico |Categorica(Nominal) | Diagnóstico enfermedad renal	|
# |DÍABETE3|	Numerico |Categorica(Nominal) | Diagnóstico Diabetes|
# |DÍABAGE2|	Numerico |Categorica(Nominal) | ¿Qué edad tenía cuando le dijeron que tenía diabetes?|
# |SEX|	Numerico | Categorica(Nominal) |Sexo del encuestado|
# |MARITAL|	Numerico |Categorica(Nominal) | Estado civil del encuestado|
# |EDUCA|	Numerico | Categorica(Ordinal) |¿Cuál es el grado o año escolar más alto que completo?|
# |RENTHOM1|	Numerico | Categorica(Nominal) |¿Es propietario o alquila su casa?|
# |NUMHHOL2|	Numerico |Categorica(Nominal)-Discreta | ¿Tiene más de un número de teléfono en su hogar?|
# |NUMPHON2|	Numerico |Categorica(Nominal) | ¿Cuántos de ese número de teléfono son residenciales?|
# |CPDEMO1|	Numerico |Categorica(Nominal) | ¿Tiene teléfono celular para uso personal?|
# |VETERAN3|	Numerico |Categorica(Nominal) | ¿Ha servido alguna vez en el servicio activo de las Fuerzas militares Armadas de los Estados Unidos?|
# |EMPLOY1|	Numerico |Categorica(Nominal) | Estado actual de empleo|
# |CHILDREN|	Numerico |Categorica(Nominal)-Discreta | Niños menores de 18 años en el hogar|
# |INCOME2|	Numerico |Categorica(Nominal) | Nivel de ingresos familiares|
# |INTERNET|	Numerico |Categorica(Nominal) | Uso del internet en los últimos 30 días|
# |WEIGHT2|	Numerico |Continua | Peso del encuestado|
# |HEIGHT3|	Numerico |Continua | Altura del encuestado|
# |PREGNANT|	Numerico |Categorica(Nominal) | Estado de embarazo actual	|
# |QLACTLM2|	Numerico |Categorica(Nominal) | Limitación de actividad por problemas de salud física, mental o emocional	|
# |USEEQUIP|	Numerico |Categorica(Nominal) | ¿tiene problemas de salud que actualmente requieran equipo especial?	|
# |BLIND|	Numerico | Categorica(Nominal) |¿Es usted ciego o tiene dificultades para ver?	|
# |DECIDE|	Numerico |Categorica(Nominal) | Dificultad para concentrarse o recordar|
# |DIFFWALK|	Numerico |Categorica(Nominal) | Dificultad para caminar o subir escaleras|
# |DIFFDRES|	Numerico |Categorica(Nominal) | Dificultad para vestirse o bañarse|
# |DIFFALON|	Numerico |Categorica(Nominal) | Dificultad para salir solo debido a una condición física, mental o emocional|
# |SMOKE100|	Numerico |Categorica(Nominal) | ¿Ha fumado al menos 100 cigarrillos en toda su vida? (5 paquetes = 100 cigarrillos)|
# |SMOKDAY2|	Numerico |Categorica(Nominal) | Frecuencia de los días que fuma actualmente|
# |STOPSMK2|	Numerico |Categorica(Nominal) | En los últimos 12 meses ¿ha dejado de fumar por un día o más porque estaba tratando de dejarlo?|
# |LASTSMK2|	Numerico |Categorica(Nominal) | Intervalos de tiempo desde la última ves que el encuestado fumo|
# |USENOW3|	Numerico |Categorica(Nominal) | Uso de productos de tabaco sin humo|
# |ALCDAY5|	Numerico |Categorica(Nominal)-Continua | Días en los últimos 30 días que consumió bebidas alcohólicas	|
# |AVEDRNK2|	Numerico |Categorica(Nominal)-Discreta | Promedio de bebidas alcohólicas por día en los últimos 30 días	|
# |DRNK3GE5|	Numerico | Categorica(Nominal)-Discreta |Consumo excesivo de alcohol en los últimos 30 días|
# |MAXDRNKS|	Numerico |Categorica(Nominal)-Discreta | Durante los últimos 30 días ¿Cuál es la mayor cantidad de tragos que tomo en cualquier ocasión?|
# |FRUITJU1|	Numerico |Categorica(Nominal)-Continua | Durante los últimos 30 días ¿Cuántas veces bebió jugos de frutas 100% puros?	|
# |FRUIT1|	Numerico |Categorica(Nominal)-Continua | En los últimos 30 días, sin contar jugos ¿Cuántas veces consumió fruta?|
# |FVBEANS|	Numerico |Categorica(Nominal)-Continua | En el último mes ¿Cuántas veces consumió frijoles o lentejas?	|
# |FVGREEN|	Numerico |Categorica(Nominal)-Continua | En el último mes ¿Cuántas veces consumiste verduras de color verde oscuro?	|
# |FVORANG|	Numerico | Categorica(Nominal)-Continua |En el último mes ¿Cuántas veces comiste vegetales de color naranja?|
# |VEGETAB1|	Numerico |Categorica(Nominal)-Continua | En el último mes ¿Cuántas veces consumiste otras verduras?	|
# |EXERANY2|	Numerico |Categorica(Nominal) | ¿Durante el último mes participo en alguna actividad para hacer ejercicio?	|
# |EXRACT11|	Numerico |Categorica(Nominal)-Discreta | Tipo de actividad Física	Numérico
# |EXEROFT1|	Numerico | Categorica(Nominal)-Continua |Veces por semana o por mes que se realizó dicha actividad física	|
# |EXERHMM1|	Numerico |Categorica(Nominal)-Continua | ¿Cuantos minutos/horas participaste en dicha actividad|
# |EXRACT21|	Numerico |Categorica(Nominal)-Discreta | Otro tipo de actividad física que brindo mayor parte del ejercicio durante el último mes|
# |EXEROFT2|	Numerico | Categorica(Nominal)-Continua |Veces por semana o por mes que se realizó dicha actividad física	|
# |EXERHMM2|	Numerico |Categorica(Nominal)-Continua | ¿Cuantos minutos/horas participaste en dicha actividad?|
# |STRENGTH|	Numerico |Categorica(Nominal)-Continua | ¿Cuántas veces realizo actividades físicas o ejercicios para fortalecer sus músculos?|
# |LMTJOIN3|	Numerico |Categorica(Nominal) | Limitación en actividades físicas debido a síntomas articulares|
# |ARTHDIS2|	Numerico |Categorica(Nominal) | ¿los síntomas articulares afectan su trabajo?|
# |ARTHSOCL|	Numerico |Categorica(Nominal) | En el último mes, ¿los síntomas articulares han interferido en sus actividades sociales normales?|
# |JOINPAIN|	Numerico |Categorica(Nominal)-Discreta | Promedio intensidad del dolor en las articulaciones en el último mes|
# |SEATBELT|	Numerico |Categorica(Ordinal) | Frecuencia uso de cinturas de seguridad en vehículos|
# |FLUSHOT6|	Numerico |Categorica(Nominal) | ¿Durante los últimos años ¿ha recibido una vacuna/aerosol contra la gripa?|
# |FLSHTMY2|	Numerico |Continua| ¿Durante que mes y año recibió su inyección/aerosol contra la gripe?	|
# |IMFVPLAC|	Numerico |Categorica(Nominal) | ¿Dónde recibió su última vacuna/aerosol contra la gripe?	|
# |PNEUVAC3|	Numerico |Categorica(Nominal) | ¿Ha recibido vacuna contra la neumonía?|
# |HIVTST6|	Numerico |Categorica(Nominal) | ¿Alguna vez se ha hecho una prueba de VIH?|
# |HIVTSTD3|	Numerico |Continua | Mes y año de la última prueba de VIH|
# |WHRTST10|	Numerico | Categorica(Nominal) |Ubicación última prueba VIH|
# |PDÍABTST|	Numerico | Categorica(Nominal) |¿Se hizo una prueba de azúcar en la sangre o diabetes en los últimos 3 años?	|
# |PREDÍAB1|	Numerico | Categorica(Nominal) |Diagnóstico de prediabetes	|
# |INSULIN|	Numerico |Categorica(Nominal) | ¿Utiliza insulina actualmente?	|
# |BLDSUGAR|	Numerico | Categorica(Nominal)-Continua |Frecuencia de control de glucosa en la sangre|
# |FEETCHK2|	Numerico |Categorica(Nominal)-Continua | ¿Con que frecuencia revisa los pies para detectar llagas o irritaciones?	|
# |DOCTDÍAB|	Numerico |Categorica(Nominal)-Discreta | En los últimos 12 meses, ¿ha visto a un profesional de la salud para control de la diabetes?|
# |CHKHEMO3|	Numerico |Categorica(Nominal)-Discreta | Número de veces que se comprueba la hemoglobina glicosilada en los últimos 12 meses|
# |FEETCHK|	Numerico |Categorica(Nominal)-Discreta | Veces que los pies comprueban si hay llagas/irritaciones|
# |EYEEXAM|	Numerico |Categorica(Nominal) | Ultimo examen de la vista con dilatación de pupilas|
# |DÍABEYE|	Numerico |Categorica(Nominal) | Alguna vez la diabetes ha afectado los ojos (retinopatía)|
# |DÍABEDU|	Numerico | Categorica(Nominal) |¿alguna vez ha tomado clases sobre cómo controlar su diabetes usted mismo?	Numérico
# |PAINACT2|	Numerico |NULOS | ¿Cuántos días les costó hacer las actividades habituales en los últimos 30 días?|
# |QLMENTL2|	Numerico |NULOS | Cantidad de días en que estuvo deprimido en los últimos 30 días|
# |QLSTRES2|	Numerico |NULOS | Cantidad de días en que estuvo ansioso en los últimos 30 días|
# |QLHLTH2|	Numerico |NULOS | Cantidad de días que estuvo lleno de energía en los últimos 30 días|
# |CAREGIV1|	Numerico |Categorica(Nominal) | Durante los últimos 30 días ¿Proporciono atención regular a familiares y amigos?|
# |CRGVREL1|	Numerico |Categorica(Nominal) | Relación con la persona a quien está cuidando|
# |CRGVLNG1|	Numerico |Categorica(Nominal) | Cantidad de tiempo brindado a esa persona|
# |CRGVHRS1|	Numerico |Categorica(Nominal) | Cantidad de horas brindada a esa persona a la semana|
# |CRGVPRB1|	Numerico |Categorica(Nominal) |Principal problema de salud que tiene la persona que se cuida|
# |CRGVPERS|	Numerico |Categorica(Nominal) | ¿En los últimos 30 días, ayudo a esa persona a dar medicamentos, alimentar, vestir o bañar?|
# |CRGVHOUS|	Numerico |Categorica(Nominal) | ¿En los últimos 30 días, ayudo a esa persona a administrar tareas del hogar?|
# |CRGVMST2|	Numerico |Categorica(Nominal) | ¿Cuál apoyo necesita más el cuidador que no está recibiendo?|
# |CRGVEXPT|	Numerico |Categorica(Nominal) | ¿Espera tener un pariente que cuidar?|
# |VIDFCLT2|	Numerico |Categorica(Nominal) | Dificultad para reconocer a un amigo al otro lado de la calle|
# |VIREDIF3|	Numerico |Categorica(Nominal) | Dificultad para leer un texto escrito|
# |VIPRFVS2|	Numerico |Categorica(Nominal) | Ultima ves que visito al proveedor de atención de la vista|
# |VINOCRE2|	Numerico |Categorica(Nominal) | Motivo por el que no asistió al oftalmólogo en los últimos 12 meses|
# |VIEYEXM2|	Numerico |Categorica(Nominal) | Cuando fue el último examen de la vista|
# |VIINSUR2|	Numerico |Categorica(Nominal) | ¿Cuenta con algún tipo de cobertura para el cuidado de los ojos?	|
# |VICTRCT4|	Numerico |Categorica(Nominal) | Diagnóstico de cataratas|
# |VIGLUMA2|	Numerico |Categorica(Nominal) | Diagnóstico glaucoma|
# |VIMACDG2|	Numerico |Categorica(Nominal) | Diagnóstico degeneración macular	|
# |CIMEMLOS|	Numerico |Categorica(Nominal) | ¿En los últimos 12 meses ha experimentado confusión o pérdida de memoria con mayor frecuencia?	|
# |CDHOUSE|	Numerico |Categorica(Nominal) | ¿En los últimos 12 meses ha abandonado tareas del día a día por confusión o pérdida de memoria?|
# |CDASSIST|	Numerico |Categorica(Nominal) | ¿Necesita ayuda debido a las actividades cotidianas debido a confusión o pérdida de memoria?|
# |CDHELP|	Numerico |Categorica(Nominal) | ¿obtiene ayuda con las tareas cotidianas cuando la necesita?|
# |CDSOCIAL|	Numerico |Categorica(Nominal) | ¿La confusión o la pérdida de memoria interfieren con el trabajo o las actividades sociales?	|
# |CDDISCUS|	Numerico |Categorica(Nominal) | ¿Ha discutido su confusión o pérdida de memoria con un profesional de la salud?|
# |WTCHSALT|	Numerico |Categorica(Nominal) | ¿Vigila la ingesta de sodio/sal?	|
# |LONGWTCH|	Numerico |Categorica(Nominal)-Continua | ¿Cuánto tiempo lleva vigilando su ingesta de sodio/sal?|
# |DRADVISE|	Numerico |Categorica(Nominal) | Recomendación médica de reducir el consumo de sodio/sal|
# |ASTHMAGE|	Numerico |Categorica(Nominal)-Discreta | Edad del diagnóstico de asma|
# |ASATTACK|	Numerico |Categorica(Nominal) | Durante los ultimo 12 meses ¿ha tenido un ataque de asma?|
# |ASERVIST|	Numerico | Categorica(Nominal)-Discreta |Durante los últimos 12 meses ¿visito una sala de emergencias por asma?|
# |ASDRVIST|	Numerico | Categorica(Nominal)-Discreta |Tratamiento urgente de asma durante los últimos 12 meses|
# |ASRCHKUP|	Numerico |Categorica(Nominal)-Discreta | Atención rutinaria del asma en los últimos 12 meses|
# |ASACTLIM|	Numerico |Categorica(Nominal)-Continua | Actividades limitadas debido al asma durante los últimos 12 meses|
# |ASYMPTOM|	Numerico |Categorica(Nominal) | Síntomas de asma en los últimos 30 días|
# |ASNOSLEP|	Numerico |Categorica(Nominal) | Dificultad para dormir en los últimos 30 días por asma|
# |ASTHMED3|	Numerico |Categorica(Nominal) | Días que uso medicamentos preventivos para el asma en los últimos 30 días|
# |ASINHALR|	Numerico |Categorica(Nominal) | Veces que uso el inhalador para el asma durante un ataque en los últimos 30 días|
# |HAREHAB1|	Numerico |Categorica(Nominal) | Rehabilitación ambulatoria después de hospitalización por ataque cardíaco|
# |STREHAB1|	Numerico |Categorica(Nominal) | Rehabilitación ambulatoria después de hospitalización por ataque cerebrovascular|
# |CVDASPRN|	Numerico |Categorica(Nominal) | Toma aspirina diariamente o cada dos días|
# |ASPUNSAF|	Numerico | Categorica(Nominal) |Su salud hace que tomar aspirina sea peligroso|
# |RLIVPAIN|	Numerico |Categorica(Nominal) | Toma aspirinas para aliviar el dolor|
# |RDUCHART|	Numerico |Categorica(Nominal) | Toma aspirinas para reducir la posibilidad de un ataque al corazón|
# |RDUCSTRK|	Numerico |Categorica(Nominal) | Toma aspirinas para reducir la posibilidad de un derrame cerebral|
# |ARTTODAY|	Numerico |Categorica(Nominal) | ¿Qué puede hacer debido a la artritis o síntomas en las articulaciones?|
# |ARTHWGT|	Numerico |Categorica(Nominal) | El profesional de la salud sugiere bajar de peso para reducir las molestias de la artritis|
# |ARTHEXER|	Numerico |Categorica(Nominal) | El profesional de la salud sugiere realizar actividad física para reducir las molestias de la artritis	|
# |ARTHEDU|	Numerico |Categorica(Nominal) | ¿alguna vez ha tomado clases sobre el manejo de la artritis?	|
# |TETANUS|	Numerico |Categorica(Nominal) | ¿Recibió la vacuna contra el tétanos?|
# |HPVADVC2|	Numerico |Categorica(Nominal) | Ha recibido vacuna contra el VPH	|
# |HPVADSHT|	Numerico |Categorica(Nominal) | Número de vacunas recibidas contra el VPH|
# |SHINGLE2|	Numerico |Categorica(Nominal) | Vacuna contra la culebrilla|
# |HADMAM|	Numerico |Categorica(Nominal) | ¿Alguna vez te has hecho una mamografía?|
# |HOWLONG|	Numerico |Categorica(Nominal) | ¿Cuánto tiempo ha pasado desde la última mamografía?|
# |HADPAP2|	Numerico |Categorica(Nominal) | ¿Alguna vez ha realizado una prueba de Papanicolau?|
# |LASTPAP2|	Numerico | Categorica(Nominal) |¿Cuánto tiempo ha pasado desde la última Papanicolau?|
# |HPVTEST|	Numerico |Categorica(Nominal) | ¿Alguna vez te has realizado una prueba de VPH?|
# |HPLSTTST|	Numerico |Categorica(Nominal) | ¿cuánto tiempo ha pasado desde la última prueba VPH?|
# |HADHYST2|	Numerico |Categorica(Nominal) | Ha tenido una histerotomía	|
# |PROFEXAM|	Numerico |Categorica(Nominal) | ¿Alguna vez tuvo un examen físico de mama por un médico?|
# |LENGEXAM|	Numerico |Categorica(Nominal) | ¿Cuánto tiempo ha pasado desde el último examen físico de los senos?|
# |BLDSTOOL|	Numerico |Categorica(Nominal) | ¿Alguna vez tuvo una prueba de heces con sangre usando un kit casero?|
# |LSTBLDS3|	Numerico |Categorica(Nominal) | Tiempo desde la última prueba de sangre en heces|
# |HADSIGM3|	Numerico |Categorica(Nominal) | ¿Alguna vez tuvo una sigmoidoscopia/colonoscopia?|
# |HADSGCO1|	Numerico |Categorica(Nominal) | ¿su última prueba fue una sigmoidoscopia o una colonoscopia?|
# |LASTSIG3|	Numerico |Categorica(Nominal) | Tiempo desde la última sigmoidoscopia/colonoscopia	|
# |PCPSAAD2|	Numerico |Categorica(Nominal) | ¿Algún profesional de la salud le ha hablado de las ventajas de una prueba PSA?|
# |PCPSADI1|	Numerico |Categorica(Nominal) | ¿Algún profesional de la salud le ha hablado de las desventajas de una prueba PSA?|
# |PCPSARE1|	Numerico |Categorica(Nominal) | ¿Su médico le ha recomendado una prueba PSA?|
# |PSATEST1|	Numerico |Categorica(Nominal) | ¿Alguna vez se ha realizado una prueba PSA?|
# |PSATIME|	Numerico |Categorica(Nominal) | Tiempo desde la última prueba de PSA|
# |PCPSARS1|	Numerico |Categorica(Nominal) | ¿Cuál fue la razón principal por la que se hizo la prueba PSA?|
# |PCPSADE1|	Numerico |Categorica(Nominal) | ¿Por qué se hizo la prueba de PSA?|
# |PCDMDECN|	Numerico |Categorica(Nominal) | ¿Quién tomo la decisión con usted de hacerse la prueba PSA?|
# |SCNTMNY1|	Numerico |Categorica(Nominal) | En los últimos 12 meses, ¿con que frecuencia estuvo estresado/preocupado por tener suficiente dinero para pagar su alquiler/hipoteca?|
# |SCNTMEL1|	Numerico |Categorica(Nominal) | En los últimos 12 meses ¿con que frecuencia estuvo estresado/preocupado por tener suficiente dinero para comida nutritiva?|
# |SCNTPAID|	Numerico |Categorica(Nominal) | ¿Cómo se le paga generalmente por el trabajo que realiza?|
# |SCNTWRK1|	Numerico |Categorica(Nominal) | ¿Aproximadamente cuantas horas trabaja en todos sus trabajos y negocios combinados?|
# |SCNTLPAD|	Numerico |Categorica(Nominal) | ¿Cómo se le pago generalmente por el trabajo que hizo?|
# |SCNTLWK1|	Numerico |Categorica(Nominal)-Discreta | ¿Cuántas horas por semana trabajo?|
# |SXORIENT|	Numerico |Categorica(Nominal) | Orientación sexual o identidad de genero|
# |TRNSGNDR|	Numerico |Categorica(Nominal) | ¿Te consideras transgénero?|
# |RCSGENDR|	Numerico |Categorica(Nominal) | Genero del niño|
# |RCSRLTN2|	Numerico |Categorica(Nominal) | Relación hacia el niño|
# |CASTHDX2|	Numerico |Categorica(Nominal) | El niño ha sido diagnosticado con asma|
# |CASTHNO2|	Numerico |Categorica(Nominal) | Actualmente el niño tiene asma|
# |EMTSUPRT|	Numerico |Categorica(Nominal) | Con que frecuencia se necesita el apoyo emocional|
# |LSATISFY|	Numerico |Categorica(Nominal) | Satisfacción con la vida|
# |ADPLEASR|	Numerico |Categorica(Nominal)-Discreta | Días en el que sintió poco placer o interés en hacer cosas en las últimas 2 semanas|
# |ADDOWN|	Numerico |Categorica(Nominal)-Discreta | Días en los que se sintió deprimido, o sin esperanza en las últimas 2 semanas	|
# |ADSLEEP|	Numerico |Categorica(Nominal)-Discreta | Días que tuvo problemas para dormir en las últimas 2 semanas|
# |ADENERGY|	Numerico |Categorica(Nominal)-Discreta | Días en los que se sintió cansado o con poca energía durante las últimas semanas|
# |ADEAT1|	Numerico |Categorica(Nominal)-Discreta | Días que comió muy poco o demasiado en las últimas semanas|
# |ADFAIL|	Numerico |Categorica(Nominal)-Discreta | Días en los que se sintió mal consigo mismo o ser un fracaso en las últimas 2 semanas|
# |ADTHINK|	Numerico |Categorica(Nominal)-Discreta | Días en los que tuvo problemas para concentrarse en las últimas 2 semanas|
# |ADMOVE|	Numerico |Categorica(Nominal)-Discreta | Días en los que se ha movido más lento o rápido de lo usual en las últimas dos semanas|
# |MISTMNT|	Numerico |Categorica(Nominal) | Recibir medicamentos o tratamiento de un profesional de la salud por un problema emocional|
# |ADANXEV|	Numerico |Categorica(Nominal) | ¿Alguna vez le dijeron que tenía un trastorno de ansiedad?|
# |QSTVER|	Numerico |Categorica(Nominal) | Identificador de versión del cuestionario|
# |QSTLANG|	Numerico |Categorica(Nominal)-Discreta | Identificador de idioma|
# |EXACTOT1|	Char |Categorica(Nominal) | Primera actividad otra descripción de la respuesta|
# |EXACTOT2|	Char |Categorica(Nominal) | Segunda actividad otra descripción de la respuesta|
# |MSCODE|	Char |Categorica(Nominal) | Código de estado metropolitano|

# %% [markdown]
# ## Exploración de los datos (1.4)
#
# Una ver explorados los datos, indique que atributos o conjuntos de atributos pueden ser prometedores para el análisis y plantee hipótesis al respecto.

# %% [markdown]
# *Repetir esta celda para cada origen de datos*
#
# **--- Origen 1 ---**
#
# Listar en las siguiente tabla únicamente los atributos candidatos a usar en el modelo.
# * Plantee posibles transformaciones
# * Plantee hipótesis que generadas de la exploración
# * Agregar otras columnas relevantes como: min, max, std, mean, mode, etc.
#
# | Atributo | Transformaciones | Hipotesis |
# | --- | --- | --- |
# |PHYSHLTH|Renombrar el atributo a SaludFisica<br>Escalar valores de dias (1-30)<br>Reemplazar el valor de ninguna(88) por 0<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)|Definir si actualmente el encuestado goza de buena salud fisica|
# |MENTHLTH|Renombrar el atributo a SaludMental<br>Solo conservar valores de dias (1-30)<br>Reemplazar el valor de 88(ninguna) por 0<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Definir si actualmente el encuestado goza de buena salud mental|
# |BPHIGH4|Renombrar el atributo a DiagHipertension<br>Convertir las categorias en 4 atributos dummy<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Diagnóstico de tensión arterial alta/hipertensión|
# |BPMEDS|Renombrar atributo a MedHipertension<br>Convertir datos si(1) y no(2) en datos booleanos (-1,1)<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Definir si actualmente el encuestado toma medicamentos para la presión arterial|
# |TOLDHI2|Renombrar atributo a DiagColesterol<br>Convertir datos si(1) y no(2) en datos booleanos(-1,1)<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)|Diagnóstico de colesterol alto en la sangre|
# |CVDINFR4|Renombrar atributo a DiagAtaqCorazon<br>Convertir datos si(1) y no(2) en datos booleanos(-1,1)<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Diagnóstico ataque al corazón|
# |CVDCRHD4|Renonmbrar atributo a DiagEnfCorazon<br>Convertir datos si(1) y no(2) en datos booleanos(-1,1)<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Diagnóstico algina de pecho o enfermedad coronaria|
# |CVDSTRK3|Renombrar atributo a DiagDerrCerebral<br>Convertir datos si(1) y no(2) en datos booleanos(-1,1)<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Diagnóstico de derrame cerebral|
# |SEX|Convertir datos hombre(1) y mujer(2) en datos booleanos(-1,1)|Sexo del encuestado|
# |WEIGHT2|Renombrar atributo a Peso<br>Convertir datos en una sola unidad(kg) y posteriormente escalar los datos<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Peso del encuestado|
# |HEIGHT3|Renombrar atributo a Altura<br>Convertir datos en una sola unidad(mt) y posteriormente escalar los datos<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Altura del encuestado|
# |PREGNANT|Renombrar atributo a Embarazo<br>Convertir datos si(1), no(2) y no sabe(7) en atributos dummy<br>Eliminar datos excedentes(9- rechazado, null)| Estado de embarazo actual	|
# |SMOKE100|Renombrar atributo a Fumar100<br>Convertir datos si(1) y no(2) en datos booleanos(-1,1)<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Definir si el encuestado a fumado alguna vez en su vida|
# |SMOKDAY2|Renombrar atributo FrecFumar<br>Convertir datos diario(1), algunos dias(2) y nada(3) en atributos dummy<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Frecuencia de los días que fuma actualmente|
# |USENOW3|Renombrar atributo UsoTabacoSinHumo<br>Convertir datos diario(1), algunos dias(2) y nada(3) en atributos dummy<br>Eliminar datos excedentes(77-no sabe, 99- rechazado, null)| Uso de productos de tabaco sin humo|
# |ALCDAY5|Renombrar atributo a CantDiaAlc30dias<br>Escalar datos discretos<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Definir el numero de bebidas alcohólicas por día en el ultimo mes	|
# |FRUITJU1|Renombrar atributo a JugFru30dias<br>Convertir los datos a una sola escala(discreta-veces por mes)<br>Escalar los datos discretos<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Definir en el mes el consumo de jugos de frutas 100% puros	|
# |FRUIT1|Renombrar atributo a Fruta30dias<br>Convertir los datos a una sola escala(discreta-veces por mes)<br>Escalar los datos discretos<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Definir en el ultimo mes el consumió fruta(no jugos)|
# |FVBEANS|Renombrar atributo a Leg30dias<br>Convertir los datos a una sola escala(discreta-veces por mes)<br>Escalar datos discretos<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Definir en el ultimo mes el consumo de legumbres	|
# |FVGREEN|Renombrar atributo VerVerde30dias<br>Convertir los datos a una sola escala(discreta-veces por mes)<br>Escalar los datos discretos<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Definir en el mes el consumo de verduras de color verde oscuro	|
# |FVORANG|Renombrar atributo VerNar30dias<br>Convertir los datos a una sola escala(discreta-veces por mes)<br>Escalar los datos discretos<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)|Definir en el mes el consumo de vegetales de color naranja|
# |VEGETAB1|Renombrar atributo OtrVer30dias<br>Convetir los datos a una sola escala(discreta-veces por mes)<br>Escalar datos discretos<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Definir en el mes el consumo de otras verduras	|
# |EXERANY2|Renombrar atributo a Ejerc30dias<br>Convertir datos si(1) y no(2) en datos booleanos(-1,1)<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Definir si el encuestado participio en actividades deportivas/ejercicio|
# |PREDÍAB1|Renombrar atributo a DiagDiabetes<br>Convertir datos si(1), solo en el embarazo(2) y no(3) en atributos dummy<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)|Diagnóstico de prediabetes	|
# |WTCHSALT|Renombrar atributo a ControlSal<br>Convertir datos si(1) y no(2) en datos booleanos(-1,1)<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Definir si el encuestado controla el consumo de sal/sodio	|
# |HAREHAB1|Renombrar atributo a RecAtaCorazon<br>Convertir datos si(1) y no(2) en datos booleanos(-1,1)<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)|Rehabilitación ambulatoria después de hospitalización por ataque cardíaco|
# |STREHAB1|Renombrar atributo a RecDerrCerebral<br>Convertir datos si(1) y no(2) en datos booleanos(-1,1)<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Rehabilitación ambulatoria después de hospitalización por ataque cerebrovascular|
# |RDUCHART|Renonmbrar atributo a AspAtacCorazon<br>Convertir datos si(1) y no(2) en datos booleanos(-1,1)<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Toma aspirinas para reducir la posibilidad de un ataque al corazón|
# |RDUCSTRK|Renombrar atributo a AspDerrCerebral<br>Convertir datos si(1) y no(2) en datos booleanos(-1,1)<br>Eliminar datos excedentes(7-no sabe, 9- rechazado, null)| Toma aspirinas para reducir la posibilidad de un derrame cerebral|
#
# <br>
# Artibutos adicionales derivados de las columnas anteriores
# <br><br>
#
# | Atributo |Tipo y Naturaleza| Transformaciones | Hipótesis |
# | --- | --- | --- | --- |
# | IMC |Continuo|Los datos deben ser escalados | Indice de masa corporal del encuestado(derivado del peso y altura) |
# | ConsVerduras |Discreto|Los datos deben estar escalado| Consumo de verduras en general del encuestado(derivado de la agrupación FVGREEN y FVORANGE) |
# | ConsFruta |Discreto|Los datos deben estar escalados| Consumo de frutas en general del encuestado(derivado de la agrupacion FRUITJU1) |
#
# <br>
# *Si en la exploración de datos surgen hipótesis que puedan modificar los objetivos del proyecto es necesario devolver a la etapa anterior para asegurarse que el proyecto sigue teniendo la misma validez.*

# %% [markdown]
# ## Calidad de los datos (1.3)
#
# En caso de identificar columnas o atributos con datos faltantes diligencie la siguiente tabla indicándolos y como se propone solventar la falta.

# %% [markdown]
# *Repetir esta celda para cada origen de datos*
#
# **--- Origen 1 ---**
# Liste los atributos donde ha identificado datos faltantes.
#
# <br>
#
# |Atributo | Cantidad total | Cantidad faltantes | Posible forma de suplir los datos faltantes |
# | --- | --- | --- | --- |
# |PHYSHLTH |441465|1|Utilizar el valor del promedio de los demas valores|
# |BPHIGH4 |441465|1|Utilizar el valor del promedio de los demas valores|
# |BPMEDS |441465|263268|Demasiados datos faltantes, no se considera como atributo primordial|
# |TOLDHI2 |441465|59154|Utilizar el valor del promedio de los demas valores|
# |CVDCRHD4 |441465|1|Utilizar el valor del promedio de los demas valores|
# |WEIGHT2 |441465|5315|Utilizar el valor del promedio de los demas valores|
# |HEIGHT3 |441465|5911|Utilizar el valor del promedio de los demas valores|
# |PREGNANT |441465|376504|Demasiados datos faltantes, no se considera como atributo primordial|
# |SMOKE100 |441465|14255|Utilizar el valor del promedio de los demas valores|
# |SMOKDAY2 |441465|257263|Demasiados datos faltantes, no se considera como atributo primordial|
# |USENOW3 |441465|14890|Utilizar el valor del promedio de los demas valores|
# |ALCDAY5 |441465|15931|Utilizar el valor del promedio de los demas valores|
# |FRUITJU1 |441465|27998|Utilizar el valor del promedio de los demas valores|
# |FRUIT1 |441465|29150|Utilizar el valor del promedio de los demas valores|
# |FVBEANS |441465|30375|Utilizar el valor del promedio de los demas valores|
# |FVGREEN |441465|31311|Utilizar el valor del promedio de los demas valores|
# |FVORANG |441465|32115|Utilizar el valor del promedio de los demas valores|
# |VEGETAB1 |441465|33138|Utilizar el valor del promedio de los demas valores|
# |EXERANY2 |441465|35444|Utilizar el valor del promedio de los demas valores|
# |PREDIAB1 |441465|358696|Utilizar el valor del promedio de los demas valores|
# |WTCHSALT |441465|400157|Demasiados datos faltantes, no se considera como atributo primordial|
# |HAREHAB1 |441465|440445|Demasiados datos faltantes, no se considera como atributo primordial|
# |STREHAB1 |441465|440762|Demasiados datos faltantes, no se considera como atributo primordial|
# |RDUCHART |441465|435837|Demasiados datos faltantes, no se considera como atributo primordial|
# |RDUCSTRK |441465|435838|Demasiados datos faltantes, no se considera como atributo primordial|

# %% [markdown]
# ## Auto valoración

# %% [markdown]
# **¿Está todo listo para el siguiente paso?**
#
# Responda a las siguientes preguntas. Es una auto valoración de lo realizado. En caso de que alguna no pueda ser respondida debería devolverse al punto correspondiente e identificar las carencias.
#
#
# *	¿Ha identificado y accedido correctamente a todos los orígenes de datos?
# <br>
# Si, el dataset se accedio desde la pagina oficial de BRFSS, se descargo y se accedio correctamente desde el archivo csv y el Google Colaborate
# <br>
# <br>
# *	¿Ha identificado atributos clave de los datos disponibles?
# <br>
# Si, se omitieron datos demograficos de la realizacion de la encuesta, y los datos que no involucraban la salud del encuestado, ademas de priorizar unicamente los datos de salud que se relacionan con la patologia que se busca predecir(Ataque cardiaco)
# <br>
# <br>
# *	¿Tiene una planificación para resolver los problemas de datos?
# Si, mediante el analisis de los atributos principales, y la calidad de los datos, se pueden determinar las transformaciones necesarias para el manejo de los datos
# <br>
